# %%
# !python -V
# Out:
# Python 3.10.12

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !python /content/gdrive/MyDrive/AI2024final/main.py --model_type BERT --preprocess 0 --part 2
# Out:
# Streaming output truncated to the last 5000 lines.
# Training:   1% 51/3750 [00:02<02:20, 26.35it/s, loss=0.358]
# Training:   1% 52/3750 [00:02<02:18, 26.68it/s, loss=0.358]
# Training:   1% 52/3750 [00:02<02:18, 26.68it/s, loss=0.407]
# Training:   1% 53/3750 [00:02<02:18, 26.68it/s, loss=0.544]
# Training:   1% 54/3750 [00:02<02:18, 26.68it/s, loss=0.406]
# Training:   1% 55/3750 [00:02<02:19, 26.52it/s, loss=0.406]
# Training:   1% 55/3750 [00:02<02:19, 26.52it/s, loss=0.891]
# Training:   1% 56/3750 [00:02<02:19, 26.52it/s, loss=0.771]
# Training:   2% 57/3750 [00:02<02:19, 26.52it/s, loss=0.661]
# Training:   2% 58/3750 [00:02<02:20, 26.34it/s, loss=0.661]
# Training:   2% 58/3750 [00:02<02:20, 26.34it/s, loss=0.4]
# Training:   2% 59/3750 [00:02<02:20, 26.34it/s, loss=0.604]
# Training:   2% 60/3750 [00:02<02:20, 26.34it/s, loss=0.409]
# Training:   2% 61/3750 [00:02<02:19, 26.48it/s, loss=0.409]
# Training:   2% 61/3750 [00:03<02:19, 26.48it/s, loss=0.363]
# ...

# %%
# !python /content/gdrive/MyDrive/AI2024final/main.py --model_type BERT --preprocess 0 --part 2
# Out:
# Streaming output truncated to the last 5000 lines.
# Training:   1% 54/3750 [00:02<02:21, 26.03it/s, loss=0.418]
# Training:   1% 55/3750 [00:02<02:21, 26.20it/s, loss=0.418]
# Training:   1% 55/3750 [00:02<02:21, 26.20it/s, loss=0.984]
# Training:   1% 56/3750 [00:02<02:20, 26.20it/s, loss=0.726]
# Training:   2% 57/3750 [00:02<02:20, 26.20it/s, loss=0.653]
# Training:   2% 58/3750 [00:02<02:21, 26.11it/s, loss=0.653]
# Training:   2% 58/3750 [00:02<02:21, 26.11it/s, loss=0.388]
# Training:   2% 59/3750 [00:02<02:21, 26.11it/s, loss=0.462]
# Training:   2% 60/3750 [00:02<02:21, 26.11it/s, loss=0.33]
# Training:   2% 61/3750 [00:02<02:20, 26.17it/s, loss=0.33]
# Training:   2% 61/3750 [00:03<02:20, 26.17it/s, loss=0.364]
# Training:   2% 62/3750 [00:03<02:20, 26.17it/s, loss=0.577]
# Training:   2% 63/3750 [00:03<02:20, 26.17it/s, loss=0.899]
# Training:   2% 64/3750 [00:03<02:19, 26.33it/s, loss=0.899]
# Training:   2% 64/3750 [00:03<02:19, 26.33it/s, loss=0.237]
# ...
